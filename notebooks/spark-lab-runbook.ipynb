# %% [markdown]
# # Apache Spark Lab Runbook
# Portfolio companion to the original lab artifact. Original documents remain preserved.
#
# ## Journey
# Environment setup, data loading, schema inspection, transformation, aggregation, validation, and modernization.
#
# ## Compatibility Lens
# Keep the historical exercise intact and annotate current status separately. For structured workloads, current Spark projects generally favor DataFrames and Spark SQL, explicit schemas, supported runtimes, and maintained data connectors. RDD examples remain useful for fundamentals.
#
# ## Evidence
# Place reviewed screenshots beside the step they demonstrate using consistent file names.
#
# ## Modern Equivalent
# Map each historical exercise to a current DataFrame or Spark SQL pattern and, where useful, a managed execution option.
#
# ## Validation
# Check schema, row counts, null behavior, partition assumptions, transformation output, and reproducibility.
#
# ## Future State
# Add the source sequence, screenshot sequence, sample data, expected outputs, and current-runtime validation notes.
